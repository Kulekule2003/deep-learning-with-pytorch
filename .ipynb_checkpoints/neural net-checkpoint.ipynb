# %%
import torch
from torch import nn

# %%
linear_layer = nn.Linear(
    in_features = 3,
    out_features = 2
)

# %%
inputs = torch.tensor([1.2, 2.3, 4])

# %%
out_puts = linear_layer(inputs)

# %%
out_puts
# Out:
# tensor([-1.4641,  1.6876], grad_fn=<ViewBackward0>)

# %%
linear_layer.bias
# Out:
# Parameter containing:
# tensor([ 0.5509, -0.2360], requires_grad=True)

# %%
linear_layer.weight
# Out:
# Parameter containing:
# tensor([[-0.3030, -0.2785, -0.2527],
#         [-0.4062,  0.2884,  0.4369]], requires_grad=True)
